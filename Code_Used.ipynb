# %%
import numpy as np
import pandas as pd

# %%
df  = pd.read_csv('./20210103_hundenamen.csv')

# %%
df
# Out:
#                          HUNDENAME  GEBURTSJAHR_HUND GESCHLECHT_HUND
# 0                            Ituma              2011               w
# 1         "Bo" Bendy of Treegarden              2020               m
# 2            "Bobby" Lord Sinclair              2009               m
# 3       "Buddy" Fortheringhay's J.              2011               m
# 4     "Fly" Showring i fly for you              2015               w
# ...                            ...               ...             ...
# 8569                     unbekannt              2010               w
# 8570                     unbekannt              2011               m
# 8571                     unbekannt              2018               m
# 8572                     unbekannt              2018               m
# 8573                     unbekannt              2017               m
#
# [8574 rows x 3 columns]

# %%
def levenshtein_ratio_and_distance(s, t, ratio_calc = False):
    # Code found in: https://www.datacamp.com/community/tutorials/fuzzy-string-python?utm_source=adwords_ppc&utm_campaignid=898687156&utm_adgroupid=48947256715&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=229765585183&utm_targetid=aud-299261629574:dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=1005469&gclid=CjwKCAjw87SHBhBiEiwAukSeUf2nboiOyxRIh07jmGL7ZzTbMy-6xQNHaj5jayLcJgAok3WflRlORBoCXoUQAvD_BwE
    rows = len(s)+1
    cols = len(t)+1
    distance = np.zeros((rows,cols),dtype = int)

    for i in range(1, rows):
        for k in range(1,cols):
            distance[i][0] = i
            distance[0][k] = k  
    for col in range(1, cols):
        for row in range(1, rows):
            if s[row-1] == t[col-1]:
                cost = 0 
            else:
                if ratio_calc == True:
                    cost = 2
                else:
                    cost = 1
            distance[row][col] = min(distance[row-1][col] + 1,      
                                 distance[row][col-1] + 1,          
                                 distance[row-1][col-1] + cost)     
    if ratio_calc == True:
        Ratio = ((len(s)+len(t)) - distance[row][col]) / (len(s)+len(t))
        return Ratio
    else:
        print("The strings are {} edits away".format(distance[row][col]))
        return distance[row][col]

# %%
def distance (string, names, name=  'Luca'):
    compare_to = string['HUNDENAME']
    print('Comparing {} with {}'.format(name,compare_to))
    dist = levenshtein_ratio_and_distance(name.lower(),compare_to.lower(), ratio_calc = False)
    
    if dist <= 1:
        names.append(compare_to)

    return names
names = []
df.apply(lambda x: distance(x, names),axis=1)
# Out:
# Comparing Luca with Ituma
# The strings are 3 edits away
# Comparing Luca with "Bo" Bendy of Treegarden
# The strings are 23 edits away
# Comparing Luca with "Bobby" Lord Sinclair
# The strings are 18 edits away
# Comparing Luca with "Buddy" Fortheringhay's J.
# The strings are 24 edits away
# Comparing Luca with "Fly" Showring i fly for you
# The strings are 27 edits away
# Comparing Luca with "Pino" Ami du soleil
# The strings are 19 edits away
# Comparing Luca with "Zappalla II" Kora v. Tüfibach
# The strings are 28 edits away
# Comparing Luca with A great Dream Kajsa of Moss-La
# The strings are 29 edits away
# Comparing Luca with A-Diana
# The strings are 6 edits away
# Comparing Luca with AISHA von der Mark
# The strings are 17 edits away
# Comparing Luca with AMBROFELLIS  VIVIAN
# The strings are 17 edits away
# Comparing Luca with Aaliyah
# The strings are 5 edits away
# Comparing Luca with Aaliyah
# The strings are 5 edits away
# Comparing Luca with Aaran vom Blauort
# ...

# %%
names
# Out:
# ['Cuca',
#  'Lua',
#  'Lua',
#  'Lua',
#  'Lua',
#  'Lua',
#  'Lua',
#  'Luba',
#  'Luca',
#  'Luca',
#  'Luca',
#  'Luca',
#  'Luca',
#  'Luca',
#  'Lucas',
#  'Luce',
#  'Luce',
#  'Luce',
#  'Lucia',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lucy',
#  'Lula',
#  'Lula',
#  'Luma',
#  'Luma',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
#  'Luna',
# ...
